# %%
import numpy as np
import pandas as pd
from dataset import utils
from importlib import reload
import re
import great_expectations as ge
import matplotlib.pyplot as plt
# %matplotlib inline
reload(utils)
# Out:
# <module 'dataset.utils' from '/Users/derekmiller/repos/qdev/dataset/utils.py'>

# %%
utils.run_tests()

# %%
fname = "/Users/derekmiller/Desktop/2018Jan17_conjoint_Centene/2019_Ambetter_Product_Design_Survey_GConly.csv"
df = pd.read_csv(fname)
df_ = pd.DataFrame()

# %%
df = utils.gen_survey_data_from_file(fname)
df.head()
# Out:
#                  RID  vers                                                 C1  \
# 0         ResponseID  vers  Assume all the following options are associate...
# 1  R_cwiomkmvhSQzhF7     2                                                  2
# 2  R_3PjENDQqsDGSOnI    36                                                  1
# 3  R_3nocRRKKQcpHKI2    43                                                  2
# 4  R_2s093Htk7qqrLed    16                                                  1
#
#                                                   C2  \
# 0  Assume all the following options are associate...
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#                                                   C3  \
# 0  Assume all the following options are associate...
# 1                                                  1
# ...

# %%
df = utils.gen_survey_data_from_file("/Users/derekmiller/Desktop/Data/PaaK_ConjData.csv")
df.head()
# Out:
#                  RID  vers  C1  C2  C3   C4
# 0  R_BFKCTSQci2SglwJ    39   2   1   1  1.0
# 1  R_3p3Tyx4AH8BN6X7    97   3   3   3  3.0
# 2  R_0GmdmGJYZJlFjuF    16   2   2   1  2.0
# 3  R_vYRsWqDGBqYLl7j    41   3   3   2  1.0
# 4  R_3e4feAni7DbzoBX    62   1   2   1  1.0

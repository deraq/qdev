# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/derekmiller/Desktop/2018Jan17_conjoint_Centene/HB_Utilities.csv")

# %%
df.head()
# Out:
#                  RID  Deductible_1  Deductible_2  Deductible_3  Deductible_4  \
# 0  R_cwiomkmvhSQzhF7      2.358876      1.671190      0.199716     -4.229782
# 1  R_3PjENDQqsDGSOnI      2.563393     -0.193931     -0.768435     -1.601027
# 2  R_3nocRRKKQcpHKI2      4.151519      1.822923     -1.570650     -4.403792
# 3  R_2s093Htk7qqrLed      0.788082      0.353131     -0.209006     -0.932207
# 4  R_3Lj3pZ3XYd8sT3B      0.778086      0.398840     -0.673014     -0.503912
#
#    AnnualOutOfPocketMaximum_1  AnnualOutOfPocketMaximum_2  \
# 0                    2.668407                    1.335622
# 1                    2.948514                    1.402707
# 2                    5.633973                    1.537966
# 3                    1.452703                    0.954015
# 4                    1.191329                    1.134110
#
#    AnnualOutOfPocketMaximum_3  AnnualOutOfPocketMaximum_4  Coinsurance_1  \
# 0                   -0.927586                   -3.076444       1.866693
# ...

# %%
factor_levels = np.array(df.columns[1:])

# %%
factor_levels
# Out:
# array(['Deductible_1', 'Deductible_2', 'Deductible_3', 'Deductible_4',
#        'AnnualOutOfPocketMaximum_1', 'AnnualOutOfPocketMaximum_2',
#        'AnnualOutOfPocketMaximum_3', 'AnnualOutOfPocketMaximum_4',
#        'Coinsurance_1', 'Coinsurance_2', 'Coinsurance_3', 'Coinsurance_4',
#        'PCPCopays_1', 'PCPCopays_2', 'PCPCopays_3', 'SpecialistCopays_1',
#        'SpecialistCopays_2', 'SpecialistCopays_3', 'GenericCopays_1',
#        'GenericCopays_2', 'GenericCopays_3'], dtype=object)
